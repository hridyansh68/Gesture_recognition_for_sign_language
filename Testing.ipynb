# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train  = pd.read_csv("sign_mnist_train/sign_mnist_train.csv")

# %%
train.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %%
train.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean      12.318813    145.419377    148.500273    151.247714    153.546531
# std        7.287552     41.358555     39.942152     39.056286     38.595247
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000    121.000000    126.000000    130.000000    133.000000
# 50%       13.000000    150.000000    153.000000    156.000000    158.000000
# 75%       19.000000    174.000000    176.000000    178.000000    179.000000
# max       24.000000    255.000000    255.000000    255.000000    255.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean     156.210891    158.411255    160.472154    162.339683    163.954799
# ...

# %%
y_train = train['label']

# %%
X_train = train.drop('label',axis = 1)

# %%
test = pd.read_csv('sign_mnist_test/sign_mnist_test.csv')
y_test = test['label']
X_test = test.drop('label',axis = 1)

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report

# %%
from sklearn.tree import DecisionTreeClassifier 
dtree_model = DecisionTreeClassifier().fit(X_train, y_train) 
dtree_predictions = dtree_model.predict(X_test)

# %%
print(classification_report(y_test,dtree_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69       331
#            1       0.73      0.51      0.60       432
#            2       0.67      0.67      0.67       310
#            3       0.41      0.46      0.43       245
#            4       0.67      0.50      0.58       498
#            5       0.45      0.57      0.51       247
#            6       0.52      0.48      0.50       348
#            7       0.67      0.54      0.60       436
#            8       0.20      0.18      0.19       288
#           10       0.34      0.31      0.32       331
#           11       0.53      0.56      0.54       209
#           12       0.39      0.33      0.36       394
#           13       0.25      0.20      0.22       291
#           14       0.39      0.32      0.35       246
#           15       0.64      0.53      0.58       347
#           16       0.49      0.85      0.62       164
# ...

# %%
from sklearn.svm import SVC 
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train, y_train) 
svm_predictions = svm_model_linear.predict(X_test)

# %%
print(classification_report(y_test,svm_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.92       331
#            1       1.00      0.95      0.97       432
#            2       0.78      0.98      0.87       310
#            3       0.89      1.00      0.94       245
#            4       0.92      1.00      0.96       498
#            5       0.68      0.83      0.75       247
#            6       0.84      0.86      0.85       348
#            7       0.95      0.88      0.91       436
#            8       0.73      0.74      0.74       288
#           10       0.62      0.40      0.48       331
#           11       0.58      0.60      0.59       209
#           12       0.87      0.69      0.77       394
#           13       0.88      0.63      0.74       291
#           14       0.88      0.65      0.75       246
#           15       0.90      1.00      0.95       347
#           16       0.76      0.95      0.85       164
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 11).fit(X_train, y_train)

# %%
knn_predictions = knn.predict(X_test)

# %%
print(classification_report(y_test,knn_predictions))

# %%
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB().fit(X_train, y_train) 
gnb_predictions = gnb.predict(X_test)

# %%
print(classification_report(y_test,gnb_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.48      0.57       331
#            1       0.96      0.40      0.56       432
#            2       0.72      0.50      0.59       310
#            3       0.60      0.40      0.48       245
#            4       0.53      0.56      0.55       498
#            5       0.39      0.26      0.31       247
#            6       0.54      0.56      0.55       348
#            7       0.85      0.39      0.53       436
#            8       0.22      0.45      0.30       288
#           10       0.27      0.41      0.33       331
#           11       0.41      0.45      0.43       209
#           12       0.37      0.19      0.25       394
#           13       0.38      0.31      0.34       291
#           14       0.37      0.49      0.42       246
#           15       0.43      0.81      0.56       347
#           16       0.29      0.60      0.39       164
# ...

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier().fit(X_train, y_train)
mlp_predictions = mlp.predict(X_test)

# %%
print(classification_report(y_test,mlp_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       331
#            1       0.00      0.00      0.00       432
#            2       0.00      0.00      0.00       310
#            3       0.00      0.00      0.00       245
#            4       0.00      0.00      0.00       498
#            5       0.00      0.00      0.00       247
#            6       0.00      0.00      0.00       348
#            7       0.00      0.00      0.00       436
#            8       0.00      0.00      0.00       288
#           10       0.00      0.00      0.00       331
#           11       0.00      0.00      0.00       209
#           12       0.12      0.01      0.01       394
#           13       0.15      0.03      0.05       291
#           14       0.00      0.00      0.00       246
#           15       0.43      0.45      0.44       347
#           16       0.69      0.70      0.69       164
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier().fit(X_train, y_train)
rfc_predictions = rfc.predict(X_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print(classification_report(y_test,rfc_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.96      0.86       331
#            1       0.79      0.83      0.81       432
#            2       0.89      0.91      0.90       310
#            3       0.56      0.79      0.66       245
#            4       0.81      0.87      0.84       498
#            5       0.69      0.83      0.75       247
#            6       0.69      0.76      0.72       348
#            7       0.87      0.81      0.84       436
#            8       0.54      0.52      0.53       288
#           10       0.50      0.48      0.49       331
#           11       0.61      0.87      0.72       209
#           12       0.68      0.59      0.63       394
#           13       0.44      0.30      0.35       291
#           14       0.85      0.69      0.76       246
#           15       0.90      0.92      0.91       347
#           16       0.81      0.98      0.89       164
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knc = KNeighborsClassifier().fit(X_train, y_train)
knc_predictions = knc.predict(X_test)

# %%
print(classification_report(y_test,knc_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88       331
#            1       0.94      0.95      0.95       432
#            2       0.94      1.00      0.97       310
#            3       0.77      0.93      0.84       245
#            4       0.81      0.96      0.88       498
#            5       0.93      0.91      0.92       247
#            6       0.91      0.94      0.92       348
#            7       0.93      0.94      0.94       436
#            8       0.86      0.66      0.75       288
#           10       0.87      0.59      0.70       331
#           11       0.94      0.89      0.91       209
#           12       0.78      0.50      0.61       394
#           13       0.76      0.58      0.66       291
#           14       1.00      0.89      0.94       246
#           15       1.00      1.00      1.00       347
#           16       0.95      1.00      0.97       164
# ...

# %%
from sklearn.linear_model import RidgeClassifier

# %%
rcc = RidgeClassifier().fit(X_train, y_train)
rcc_predictions = rcc.predict(X_test)

# %%
print(classification_report(y_test,rcc_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.77      0.61       331
#            1       0.65      0.69      0.67       432
#            2       0.75      0.78      0.76       310
#            3       0.37      0.62      0.46       245
#            4       0.62      0.50      0.56       498
#            5       0.41      0.47      0.44       247
#            6       0.59      0.45      0.51       348
#            7       0.72      0.53      0.61       436
#            8       0.19      0.10      0.13       288
#           10       0.30      0.31      0.30       331
#           11       0.34      0.32      0.33       209
#           12       0.32      0.24      0.27       394
#           13       0.28      0.21      0.24       291
#           14       0.38      0.34      0.36       246
#           15       0.28      0.12      0.17       347
#           16       0.27      0.49      0.35       164
# ...

# %%
from sklearn.linear_model import RidgeClassifierCV

# %%
rccc = RidgeClassifierCV().fit(X_train, y_train)
rccc_predictions = rccc.predict(X_test)

# %%
print(classification_report(y_test,rccc_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.77      0.61       331
#            1       0.65      0.69      0.67       432
#            2       0.75      0.78      0.76       310
#            3       0.37      0.62      0.46       245
#            4       0.62      0.50      0.56       498
#            5       0.41      0.47      0.44       247
#            6       0.59      0.45      0.51       348
#            7       0.72      0.53      0.61       436
#            8       0.19      0.10      0.13       288
#           10       0.30      0.31      0.30       331
#           11       0.34      0.32      0.33       209
#           12       0.32      0.24      0.27       394
#           13       0.28      0.21      0.24       291
#           14       0.38      0.34      0.36       246
#           15       0.28      0.12      0.17       347
#           16       0.27      0.49      0.35       164
# ...
